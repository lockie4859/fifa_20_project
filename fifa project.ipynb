# %%
import numpy as np

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
from matplotlib import pyplot as plt

# %%
fifa=pd.read_csv('players_20.csv')

# %%
fifa.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  24-06-1987
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  05-02-1985
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  05-02-1992
# 3           J. Oblak                            Jan Oblak   26  07-01-1993
# 4          E. Hazard                          Eden Hazard   28  07-01-1991
#
#    height_cm  weight_kg nationality                 club  ...   lwb   ldm  \
# 0        170         72   Argentina         FC Barcelona  ...  68+2  66+2
# 1        187         83    Portugal             Juventus  ...  65+3  61+3
# 2        175         68      Brazil  Paris Saint-Germain  ...  66+3  61+3
# 3        188         87    Slovenia      Atlético Madrid  ...   NaN   NaN
# 4        175         74     Belgium          Real Madrid  ...  66+3  63+3
#
#     cdm   rdm   rwb    lb   lcb    cb   rcb    rb
# 0  66+2  66+2  68+2  63+2  52+2  52+2  52+2  63+2
# 1  61+3  61+3  65+3  61+3  53+3  53+3  53+3  61+3
# 2  61+3  61+3  66+3  61+3  46+3  46+3  46+3  61+3
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4  63+3  63+3  66+3  61+3  49+3  49+3  49+3  61+3
#
# [5 rows x 104 columns]

# %%
#check columns 
for col in fifa.columns:
    print(col)
# Out:
# sofifa_id
# player_url
# short_name
# long_name
# age
# dob
# height_cm
# weight_kg
# nationality
# club
# overall
# potential
# value_eur
# wage_eur
# player_positions
# preferred_foot
# international_reputation
# weak_foot
# skill_moves
# work_rate
# body_type
# real_face
# release_clause_eur
# player_tags
# team_position
# team_jersey_number
# loaned_from
# joined
# contract_valid_until
# nation_position
# nation_jersey_number
# pace
# shooting
# passing
# dribbling
# defending
# physic
# gk_diving
# gk_handling
# gk_kicking
# gk_reflexes
# gk_speed
# gk_positioning
# player_traits
# attacking_crossing
# attacking_finishing
# attacking_heading_accuracy
# attacking_short_passing
# attacking_volleys
# skill_dribbling
# skill_curve
# skill_fk_accuracy
# skill_long_passing
# skill_ball_control
# movement_acceleration
# movement_sprint_speed
# movement_agility
# movement_reactions
# movement_balance
# power_shot_power
# power_jumping
# power_stamina
# power_strength
# power_long_shots
# mentality_aggression
# mentality_interceptions
# mentality_positioning
# mentality_vision
# mentality_penalties
# mentality_composure
# defending_marking
# defending_standing_tackle
# defending_sliding_tackle
# goalkeeping_diving
# goalkeeping_handling
# goalkeeping_kicking
# goalkeeping_positioning
# goalkeeping_reflexes
# ls
# st
# rs
# lw
# lf
# cf
# rf
# rw
# lam
# cam
# ram
# lm
# lcm
# cm
# rcm
# rm
# lwb
# ldm
# cdm
# rdm
# rwb
# lb
# lcb
# cb
# rcb
# rb

# %%
fifa.tail()
# Out:
#        sofifa_id                                         player_url  \
# 18273     245006  https://sofifa.com/player/245006/shuai-shao/20...
# 18274     250995  https://sofifa.com/player/250995/mingjie-xiao/...
# 18275     252332  https://sofifa.com/player/252332/wei-zhang/20/...
# 18276     251110  https://sofifa.com/player/251110/haijian-wang/...
# 18277     233449  https://sofifa.com/player/233449/ximing-pan/20...
#
#          short_name     long_name  age         dob  height_cm  weight_kg  \
# 18273    Shao Shuai            邵帅   22  10-03-1997        186         79
# 18274  Xiao Mingjie  Mingjie Xiao   22  01-01-1997        177         66
# 18275     Zhang Wei            张威   19  16-05-2000        186         75
# 18276  Wang Haijian           汪海健   18  02-08-2000        185         74
# 18277    Pan Ximing           潘喜明   26  11-01-1993        182         78
#
#       nationality                           club  ...   lwb   ldm   cdm   rdm  \
# 18273    China PR               Beijing Renhe FC  ...  43+2  42+2  42+2  42+2
# 18274    China PR               Shanghai SIPG FC  ...  44+2  43+2  43+2  43+2
# 18275    China PR         Hebei China Fortune FC  ...  47+2  49+2  49+2  49+2
# 18276    China PR  Shanghai Greenland Shenhua FC  ...  48+2  48+2  48+2  48+2
# 18277    China PR         Hebei China Fortune FC  ...  48+2  49+2  49+2  49+2
#
#         rwb    lb   lcb    cb   rcb    rb
# 18273  43+2  45+2  46+2  46+2  46+2  45+2
# 18274  44+2  46+2  47+2  47+2  47+2  46+2
# 18275  47+2  47+2  49+2  49+2  49+2  47+2
# 18276  48+2  48+2  49+2  49+2  49+2  48+2
# 18277  48+2  48+2  50+2  50+2  50+2  48+2
#
# [5 rows x 104 columns]

# %%
fifa.shape
# Out:
# (18278, 104)

# %%
fifa.describe()
# Out:
#            sofifa_id           age     height_cm     weight_kg       overall  \
# count   18278.000000  18278.000000  18278.000000  18278.000000  18278.000000
# mean   219738.864482     25.283291    181.362184     75.276343     66.244994
# std     27960.200461      4.656964      6.756961      7.047744      6.949953
# min       768.000000     16.000000    156.000000     50.000000     48.000000
# 25%    204445.500000     22.000000    177.000000     70.000000     62.000000
# 50%    226165.000000     25.000000    181.000000     75.000000     66.000000
# 75%    240795.750000     29.000000    186.000000     80.000000     71.000000
# max    252905.000000     42.000000    205.000000    110.000000     94.000000
#
#           potential     value_eur       wage_eur  international_reputation  \
# count  18278.000000  1.827800e+04   18278.000000              18278.000000
# mean      71.546887  2.484038e+06    9456.942773                  1.103184
# std        6.139669  5.585481e+06   21351.714095                  0.378861
# min       49.000000  0.000000e+00       0.000000                  1.000000
# 25%       67.000000  3.250000e+05    1000.000000                  1.000000
# 50%       71.000000  7.000000e+05    3000.000000                  1.000000
# 75%       75.000000  2.100000e+06    8000.000000                  1.000000
# max       95.000000  1.055000e+08  565000.000000                  5.000000
#
#           weak_foot  ...  mentality_penalties  mentality_composure  \
# count  18278.000000  ...         18278.000000         18278.000000
# mean       2.944250  ...            48.383357            58.528778
# std        0.664656  ...            15.708099            11.880840
# min        1.000000  ...             7.000000            12.000000
# 25%        3.000000  ...            39.000000            51.000000
# 50%        3.000000  ...            49.000000            60.000000
# 75%        3.000000  ...            60.000000            67.000000
# max        5.000000  ...            92.000000            96.000000
#
#        defending_marking  defending_standing_tackle  defending_sliding_tackle  \
# count       18278.000000               18278.000000              18278.000000
# mean           46.848889                  47.640333                 45.606631
# std            20.091287                  21.585641                 21.217734
# min             1.000000                   5.000000                  3.000000
# 25%            29.000000                  27.000000                 24.000000
# 50%            52.000000                  55.000000                 52.000000
# 75%            64.000000                  66.000000                 64.000000
# max            94.000000                  92.000000                 90.000000
#
#        goalkeeping_diving  goalkeeping_handling  goalkeeping_kicking  \
# count        18278.000000          18278.000000         18278.000000
# mean            16.572765             16.354853            16.212934
# std             17.738069             16.996925            16.613665
# min              1.000000              1.000000             1.000000
# 25%              8.000000              8.000000             8.000000
# 50%             11.000000             11.000000            11.000000
# 75%             14.000000             14.000000            14.000000
# max             90.000000             92.000000            93.000000
#
#        goalkeeping_positioning  goalkeeping_reflexes
# count             18278.000000          18278.000000
# mean                 16.368038             16.709924
# std                  17.136497             18.038125
# min                   1.000000              1.000000
# 25%                   8.000000              8.000000
# 50%                  11.000000             11.000000
# 75%                  14.000000             14.000000
# max                  91.000000             92.000000
#
# [8 rows x 61 columns]

# %%
fifa['nationality'].value_counts()
# Out:
# England                1667
# Germany                1216
# Spain                  1035
# France                  984
# Argentina               886
#                        ...
# Liberia                   1
# São Tomé & Príncipe       1
# Puerto Rico               1
# Bahrain                   1
# Indonesia                 1
# Name: nationality, Length: 162, dtype: int64

# %%
fifa['nationality'].value_counts()[0:10]
# Out:
# England        1667
# Germany        1216
# Spain          1035
# France          984
# Argentina       886
# Brazil          824
# Italy           732
# Colombia        591
# Japan           453
# Netherlands     416
# Name: nationality, dtype: int64

# %%
fifa['nationality'].value_counts()[0:10].keys()
# Out:
# Index(['England', 'Germany', 'Spain', 'France', 'Argentina', 'Brazil', 'Italy',
#        'Colombia', 'Japan', 'Netherlands'],
#       dtype='object')

# %%
list(fifa['nationality'].value_counts()[0:5])
# Out:
# [1667, 1216, 1035, 984, 886]

# %%
plt.bar(list(fifa['nationality'].value_counts()[0:5].keys()),list(fifa['nationality'].value_counts()[0:5]),color='g')
plt.xlabel('countries')
plt.ylabel('number of players')
plt.title('Nationality')
plt.show()

# %%
players_salary=fifa[['short_name','wage_eur']]

# %%
players_salary.head()
# Out:
#           short_name  wage_eur
# 0           L. Messi    565000
# 1  Cristiano Ronaldo    405000
# 2          Neymar Jr    290000
# 3           J. Oblak    125000
# 4          E. Hazard    470000

# %%
players_salary=players_salary.sort_values(by=['wage_eur'],ascending=False)

# %%
players_salary.head()
# Out:
#            short_name  wage_eur
# 0            L. Messi    565000
# 4           E. Hazard    470000
# 1   Cristiano Ronaldo    405000
# 5        K. De Bruyne    370000
# 22       A. Griezmann    370000

# %%
plt.figure(figsize=(9,5))
plt.bar(list(players_salary['short_name'])[0:5],list(players_salary['wage_eur'])[0:5],color=('green','blue','orange','pink','black'))
plt.show()

# %%
#finding nationality argentina or not
fifa['nationality']=='Argentina'
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 18273    False
# 18274    False
# 18275    False
# 18276    False
# 18277    False
# Name: nationality, Length: 18278, dtype: bool

# %%
Argentina=fifa[fifa['nationality']=='Argentina']

# %%
Argentina.head(10)
# Out:
#      sofifa_id                                         player_url  \
# 0       158023  https://sofifa.com/player/158023/lionel-messi/...
# 17      153079  https://sofifa.com/player/153079/sergio-aguero...
# 23      211110  https://sofifa.com/player/211110/paulo-dybala/...
# 66      183898  https://sofifa.com/player/183898/angel-di-mari...
# 93      201399  https://sofifa.com/player/201399/mauro-icardi/...
# 97      143076  https://sofifa.com/player/143076/alejandro-gom...
# 98      167664  https://sofifa.com/player/167664/gonzalo-higua...
# 159     226226  https://sofifa.com/player/226226/giovani-lo-ce...
# 210     170481  https://sofifa.com/player/170481/ezequiel-gara...
# 213     178562  https://sofifa.com/player/178562/ever-banega/2...
#
#       short_name                          long_name  age         dob  \
# 0       L. Messi     Lionel Andrés Messi Cuccittini   32  24-06-1987
# 17     S. Agüero  Sergio Leonel Agüero del Castillo   31  02-06-1988
# 23     P. Dybala        Paulo Bruno Exequiel Dybala   25  15-11-1993
# 66   A. Di María    Ángel Fabián Di María Hernández   31  14-02-1988
# 93     M. Icardi        Mauro Emanuel Icardi Rivero   26  19-02-1993
# 97      A. Gómez              Alejandro Darío Gómez   31  15-02-1988
# 98    G. Higuaín            Gonzalo Gerardo Higuaín   31  10-12-1987
# 159  G. Lo Celso                   Giovani Lo Celso   23  09-04-1996
# 210     E. Garay             Ezequiel Marcelo Garay   32  10-10-1986
# 213    E. Banega      Éver Maximiliano David Banega   31  29-06-1988
#
#      height_cm  weight_kg nationality                 club  ...   lwb   ldm  \
# 0          170         72   Argentina         FC Barcelona  ...  68+2  66+2
# 17         173         70   Argentina      Manchester City  ...  60+3  58+3
# 23         177         75   Argentina             Juventus  ...  68+3  64+3
# 66         180         69   Argentina  Paris Saint-Germain  ...  69+3  66+3
# 93         181         75   Argentina                Inter  ...  53+3  52+3
# 97         165         68   Argentina             Atalanta  ...  64+3  60+3
# 98         186         89   Argentina             Juventus  ...  53+3  52+3
# 159        177         68   Argentina    Tottenham Hotspur  ...  75+2  75+2
# 210        189         90   Argentina          Valencia CF  ...  71+3  76+3
# 213        174         71   Argentina           Sevilla FC  ...  77+3  80+3
#
#       cdm   rdm   rwb    lb   lcb    cb   rcb    rb
# 0    66+2  66+2  68+2  63+2  52+2  52+2  52+2  63+2
# 17   58+3  58+3  60+3  56+3  50+3  50+3  50+3  56+3
# 23   64+3  64+3  68+3  64+3  54+3  54+3  54+3  64+3
# 66   66+3  66+3  69+3  66+3  57+3  57+3  57+3  66+3
# 93   52+3  52+3  53+3  51+3  50+3  50+3  50+3  51+3
# 97   60+3  60+3  64+3  60+3  48+3  48+3  48+3  60+3
# 98   52+3  52+3  53+3  49+3  47+3  47+3  47+3  49+3
# 159  75+2  75+2  75+2  72+2  68+2  68+2  68+2  72+2
# 210  76+3  76+3  71+3  72+3  80+3  80+3  80+3  72+3
# 213  80+3  80+3  77+3  76+3  75+3  75+3  75+3  76+3
#
# [10 rows x 104 columns]

# %%
Argentina.sort_values(by=['height_cm'],ascending=False).head()
# Out:
#       sofifa_id                                         player_url  \
# 6542     223071  https://sofifa.com/player/223071/fernando-pell...
# 6067     222889  https://sofifa.com/player/222889/lucas-acevedo...
# 1786     205186  https://sofifa.com/player/205186/paulo-gazzani...
# 1141     152993  https://sofifa.com/player/152993/renato-civell...
# 519      179847  https://sofifa.com/player/179847/federico-fazi...
#
#          short_name              long_name  age         dob  height_cm  \
# 6542  F. Pellegrino    Fernando Pellegrino   33  31-03-1986        197
# 6067     L. Acevedo          Lucas Acevedo   27  08-11-1991        197
# 1786   P. Gazzaniga   Paulo Dino Gazzaniga   27  02-01-1992        196
# 1141     R. Civelli         Renato Civelli   35  14-10-1983        195
# 519        F. Fazio  Federico Julián Fazio   32  17-03-1987        195
#
#       weight_kg nationality                    club  ...   lwb   ldm   cdm  \
# 6542         90   Argentina   Club Atlético Huracán  ...   NaN   NaN   NaN
# 6067         97   Argentina     Club Atlético Colón  ...  56+2  61+2  61+2
# 1786         90   Argentina       Tottenham Hotspur  ...   NaN   NaN   NaN
# 1141         89   Argentina  Club Atlético Banfield  ...  62+2  70+2  70+2
# 519          85   Argentina                    Roma  ...  65+3  73+3  73+3
#
#        rdm   rwb    lb   lcb    cb   rcb    rb
# 6542   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 6067  61+2  56+2  59+2  68+2  68+2  68+2  59+2
# 1786   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1141  70+2  62+2  65+2  75+2  75+2  75+2  65+2
# 519   73+3  65+3  68+3  79+3  79+3  79+3  68+3
#
# [5 rows x 104 columns]

# %%
Argentina.sort_values(by=['weight_kg'],ascending=False).head()
# Out:
#       sofifa_id                                         player_url  \
# 9006     235925  https://sofifa.com/player/235925/gaston-gomez/...
# 6067     222889  https://sofifa.com/player/222889/lucas-acevedo...
# 2174     227275  https://sofifa.com/player/227275/agustin-rossi...
# 682      176919  https://sofifa.com/player/176919/nahuel-guzman...
# 792      214979  https://sofifa.com/player/214979/juan-musso/20...
#
#       short_name              long_name  age         dob  height_cm  \
# 9006    G. Gómez           Gastón Gómez   23  04-03-1996        190
# 6067  L. Acevedo          Lucas Acevedo   27  08-11-1991        197
# 2174    A. Rossi   Agustín Daniel Rossi   23  21-08-1995        193
# 682    N. Guzmán  Nahuel Ignacio Guzmán   33  10-02-1986        193
# 792     J. Musso             Juan Musso   25  06-05-1994        191
#
#       weight_kg nationality                 club  ...   lwb   ldm   cdm   rdm  \
# 9006         99   Argentina          Racing Club  ...   NaN   NaN   NaN   NaN
# 6067         97   Argentina  Club Atlético Colón  ...  56+2  61+2  61+2  61+2
# 2174         95   Argentina  Club Atlético Lanús  ...   NaN   NaN   NaN   NaN
# 682          94   Argentina      Tigres U.A.N.L.  ...   NaN   NaN   NaN   NaN
# 792          93   Argentina              Udinese  ...   NaN   NaN   NaN   NaN
#
#        rwb    lb   lcb    cb   rcb    rb
# 9006   NaN   NaN   NaN   NaN   NaN   NaN
# 6067  56+2  59+2  68+2  68+2  68+2  59+2
# 2174   NaN   NaN   NaN   NaN   NaN   NaN
# 682    NaN   NaN   NaN   NaN   NaN   NaN
# 792    NaN   NaN   NaN   NaN   NaN   NaN
#
# [5 rows x 104 columns]

# %%
Argentina.sort_values(by=['wage_eur'],ascending=False).head()
# Out:
#     sofifa_id                                         player_url   short_name  \
# 0      158023  https://sofifa.com/player/158023/lionel-messi/...     L. Messi
# 17     153079  https://sofifa.com/player/153079/sergio-aguero...    S. Agüero
# 23     211110  https://sofifa.com/player/211110/paulo-dybala/...    P. Dybala
# 98     167664  https://sofifa.com/player/167664/gonzalo-higua...   G. Higuaín
# 66     183898  https://sofifa.com/player/183898/angel-di-mari...  A. Di María
#
#                             long_name  age         dob  height_cm  weight_kg  \
# 0      Lionel Andrés Messi Cuccittini   32  24-06-1987        170         72
# 17  Sergio Leonel Agüero del Castillo   31  02-06-1988        173         70
# 23        Paulo Bruno Exequiel Dybala   25  15-11-1993        177         75
# 98            Gonzalo Gerardo Higuaín   31  10-12-1987        186         89
# 66    Ángel Fabián Di María Hernández   31  14-02-1988        180         69
#
#    nationality                 club  ...   lwb   ldm   cdm   rdm   rwb    lb  \
# 0    Argentina         FC Barcelona  ...  68+2  66+2  66+2  66+2  68+2  63+2
# 17   Argentina      Manchester City  ...  60+3  58+3  58+3  58+3  60+3  56+3
# 23   Argentina             Juventus  ...  68+3  64+3  64+3  64+3  68+3  64+3
# 98   Argentina             Juventus  ...  53+3  52+3  52+3  52+3  53+3  49+3
# 66   Argentina  Paris Saint-Germain  ...  69+3  66+3  66+3  66+3  69+3  66+3
#
#      lcb    cb   rcb    rb
# 0   52+2  52+2  52+2  63+2
# 17  50+3  50+3  50+3  56+3
# 23  54+3  54+3  54+3  64+3
# 98  47+3  47+3  47+3  49+3
# 66  57+3  57+3  57+3  66+3
#
# [5 rows x 104 columns]

# %%
Argentina[['short_name','wage_eur']].sort_values(by=['wage_eur'],ascending=False).head()
# Out:
#      short_name  wage_eur
# 0      L. Messi    565000
# 17    S. Agüero    300000
# 23    P. Dybala    215000
# 98   G. Higuaín    175000
# 66  A. Di María    150000

# %%
#shooting

players_shooting=fifa[['short_name','shooting']]

# %%
players_shooting.sort_values(by=['shooting'],ascending=False).head()
# Out:
#             short_name  shooting
# 1    Cristiano Ronaldo      93.0
# 0             L. Messi      92.0
# 12             H. Kane      91.0
# 17           S. Agüero      90.0
# 205    F. Quagliarella      89.0

# %%
#defending
players_defending=fifa[['short_name','defending','nationality','club']]

# %%
players_defending.sort_values(by=['defending'],ascending=False).head()
# Out:
#       short_name  defending  nationality               club
# 16  G. Chiellini       90.0        Italy           Juventus
# 7    V. van Dijk       90.0  Netherlands          Liverpool
# 11  K. Koulibaly       89.0      Senegal             Napoli
# 35      D. Godín       89.0      Uruguay              Inter
# 49    M. Hummels       89.0      Germany  Borussia Dortmund

# %%
#extract real madrid players
mufc=fifa[fifa['club']=='Manchester United']

# %%
mufc.sort_values(by=['shooting'],ascending=False).head()
# Out:
#      sofifa_id                                         player_url  \
# 171     231677  https://sofifa.com/player/231677/marcus-rashfo...
# 24      195864  https://sofifa.com/player/195864/paul-pogba/20...
# 163     211300  https://sofifa.com/player/211300/anthony-marti...
# 301     184941  https://sofifa.com/player/184941/alexis-sanche...
# 319     207494  https://sofifa.com/player/207494/jesse-lingard...
#
#       short_name                         long_name  age         dob  \
# 171  M. Rashford                   Marcus Rashford   21  31-10-1997
# 24      P. Pogba                        Paul Pogba   26  15-03-1993
# 163   A. Martial                   Anthony Martial   23  05-12-1995
# 301   A. Sánchez  Alexis Alejandro Sánchez Sánchez   30  19-12-1988
# 319   J. Lingard                     Jesse Lingard   26  15-12-1992
#
#      height_cm  weight_kg nationality               club  ...   lwb   ldm  \
# 171        186         70     England  Manchester United  ...  65+2  62+2
# 24         191         84      France  Manchester United  ...  76+3  77+3
# 163        184         76      France  Manchester United  ...  64+3  59+3
# 301        169         62       Chile  Manchester United  ...  63+3  62+3
# 319        175         62     England  Manchester United  ...  71+2  68+2
#
#       cdm   rdm   rwb    lb   lcb    cb   rcb    rb
# 171  62+2  62+2  65+2  62+2  57+2  57+2  57+2  62+2
# 24   77+3  77+3  76+3  74+3  72+3  72+3  72+3  74+3
# 163  59+3  59+3  64+3  60+3  54+3  54+3  54+3  60+3
# 301  62+3  62+3  63+3  60+3  56+3  56+3  56+3  60+3
# 319  68+2  68+2  71+2  68+2  63+2  63+2  63+2  68+2
#
# [5 rows x 104 columns]

# %%
mufc.sort_values(by=['defending'],ascending=False).head()
# Out:
#      sofifa_id                                         player_url  \
# 335     221660  https://sofifa.com/player/221660/victor-lindel...
# 280     203263  https://sofifa.com/player/203263/harry-maguire...
# 347     205988  https://sofifa.com/player/205988/luke-shaw/20/...
# 396     191202  https://sofifa.com/player/191202/nemanja-matic...
# 571     229880  https://sofifa.com/player/229880/aaron-wan-bis...
#
#          short_name                long_name  age         dob  height_cm  \
# 335     V. Lindelöf  Victor Nilsson Lindelöf   24  17-07-1994        187
# 280      H. Maguire            Harry Maguire   26  05-03-1993        194
# 347         L. Shaw                Luke Shaw   23  12-07-1995        181
# 396        N. Matić            Nemanja Matić   30  01-08-1988        194
# 571  A. Wan-Bissaka        Aaron Wan-Bissaka   21  26-11-1997        183
#
#      weight_kg nationality               club  ...   lwb   ldm   cdm   rdm  \
# 335         80      Sweden  Manchester United  ...  76+2  79+2  79+2  79+2
# 280        100     England  Manchester United  ...  70+2  78+2  78+2  78+2
# 347         75     England  Manchester United  ...  80+2  78+2  78+2  78+2
# 396         85      Serbia  Manchester United  ...  74+3  79+3  79+3  79+3
# 571         72     England  Manchester United  ...  78+2  74+2  74+2  74+2
#
#       rwb    lb   lcb    cb   rcb    rb
# 335  76+2  77+2  80+2  80+2  80+2  77+2
# 280  70+2  72+2  81+2  81+2  81+2  72+2
# 347  80+2  80+2  79+2  79+2  79+2  80+2
# 396  74+3  73+3  78+3  78+3  78+3  73+3
# 571  78+2  78+2  76+2  76+2  76+2  78+2
#
# [5 rows x 104 columns]

# %%
mufc.sort_values(by=['wage_eur'],ascending=False).head()
# Out:
#      sofifa_id                                         player_url  short_name  \
# 24      195864  https://sofifa.com/player/195864/paul-pogba/20...    P. Pogba
# 14      193080  https://sofifa.com/player/193080/david-de-gea-...      De Gea
# 301     184941  https://sofifa.com/player/184941/alexis-sanche...  A. Sánchez
# 163     211300  https://sofifa.com/player/211300/anthony-marti...  A. Martial
# 295     178088  https://sofifa.com/player/178088/juan-manuel-m...   Juan Mata
#
#                             long_name  age         dob  height_cm  weight_kg  \
# 24                         Paul Pogba   26  15-03-1993        191         84
# 14              David De Gea Quintana   28  07-11-1990        192         82
# 301  Alexis Alejandro Sánchez Sánchez   30  19-12-1988        169         62
# 163                   Anthony Martial   23  05-12-1995        184         76
# 295           Juan Manuel Mata García   31  28-04-1988        170         63
#
#     nationality               club  ...   lwb   ldm   cdm   rdm   rwb    lb  \
# 24       France  Manchester United  ...  76+3  77+3  77+3  77+3  76+3  74+3
# 14        Spain  Manchester United  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 301       Chile  Manchester United  ...  63+3  62+3  62+3  62+3  63+3  60+3
# 163      France  Manchester United  ...  64+3  59+3  59+3  59+3  64+3  60+3
# 295       Spain  Manchester United  ...  60+3  59+3  59+3  59+3  60+3  55+3
#
#       lcb    cb   rcb    rb
# 24   72+3  72+3  72+3  74+3
# 14    NaN   NaN   NaN   NaN
# 301  56+3  56+3  56+3  60+3
# 163  54+3  54+3  54+3  60+3
# 295  45+3  45+3  45+3  55+3
#
# [5 rows x 104 columns]

# %%
mufc['nationality'].value_counts()
# Out:
# England        15
# Spain           2
# France          2
# Argentina       2
# Brazil          2
# Netherlands     2
# Chile           1
# Sweden          1
# Serbia          1
# Ivory Coast     1
# Scotland        1
# Portugal        1
# Italy           1
# Wales           1
# Name: nationality, dtype: int64
